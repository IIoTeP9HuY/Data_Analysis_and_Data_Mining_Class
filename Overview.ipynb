# %% [markdown]
# # Overview of dataset
# ### Course: Data Analysis and Data Mining
# #### Authors: Andrey Kashin, Irina Osipova

# %% [markdown]
# Dataset source: https://www.backblaze.com/hard-drive-test-data.html

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Exploring sample of the data:

# %%
sample = pd.read_csv("2014/2014-05-19.csv")

print("Size of sample: {}".format(len(sample)))
print("Number of features: {}".format(len(sample.columns)))

sample.head()
# Out:
# Size of sample: 33342
# Number of features: 85
#          date   serial_number                    model  capacity_bytes  \
# 0  2014-05-19  MJ0351YNG9Z0XA  Hitachi HDS5C3030ALA630   3000592982016
# 1  2014-05-19  MJ0351YNG9Z7LA  Hitachi HDS5C3030ALA630   3000592982016
# 2  2014-05-19  MJ0351YNGABYAA  Hitachi HDS5C3030ALA630   3000592982016
# 3  2014-05-19  PL1321LAG34XWH  Hitachi HDS5C4040ALE630   4000787030016
# 4  2014-05-19  PL1311LAG2205A  Hitachi HDS5C4040ALE630   4000787030016
#
#    failure  smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 0        0                 100            0                 135          108
# 1        0                 100            0                 136          104
# 2        0                 100            0                 136          104
# 3        0                 100            0                 134          101
# 4        0                 100            0                 134          102
#
#    smart_3_normalized      ...        smart_250_normalized  smart_250_raw  \
# 0                 143      ...                         NaN            NaN
# 1                 124      ...                         NaN            NaN
# 2                 137      ...                         NaN            NaN
# 3                 131      ...                         NaN            NaN
# 4                 130      ...                         NaN            NaN
#
#    smart_251_normalized  smart_251_raw  smart_252_normalized  smart_252_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_254_normalized  smart_254_raw  smart_255_normalized  smart_255_raw
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
# [5 rows x 85 columns]

# %% [markdown]
# ### Simple statistics for numeric features of sample:

# %%
sample.describe()
# Out:
#        capacity_bytes       failure  smart_1_normalized   smart_1_raw  \
# count    3.334200e+04  33342.000000        33342.000000  3.334200e+04
# mean     3.092502e+12      0.000090          112.557435  6.022833e+07
# std      9.742706e+11      0.009485           21.890581  7.853471e+07
# min      8.002636e+10      0.000000           65.000000  0.000000e+00
# 25%      2.000399e+12      0.000000          100.000000  0.000000e+00
# 50%      3.000593e+12      0.000000          109.000000  3.932160e+05
# 75%      4.000787e+12      0.000000          117.000000  1.204619e+08
# max      4.000787e+12      1.000000          200.000000  4.588831e+08
#
#        smart_2_normalized   smart_2_raw  smart_3_normalized   smart_3_raw  \
# count        15136.000000  15136.000000        33342.000000  33342.000000
# mean           120.392640     59.005087          110.189371    479.666037
# std             18.220692     50.346668           21.611724   1149.627401
# min            100.000000      0.000000           70.000000      0.000000
# 25%            100.000000      0.000000           92.000000      0.000000
# 50%            133.000000     97.000000          100.000000      0.000000
# 75%            135.000000    103.000000          124.000000    566.000000
# max            252.000000    195.000000          253.000000   9670.000000
#
#        smart_4_normalized   smart_4_raw      ...        smart_250_normalized  \
# count        33342.000000  33342.000000      ...                          97
# mean            99.996701     24.140154      ...                           1
# std              0.178779    190.540512      ...                           0
# min             83.000000      1.000000      ...                           1
# 25%            100.000000      8.000000      ...                           1
# 50%            100.000000     16.000000      ...                           1
# 75%            100.000000     25.000000      ...                           1
# max            100.000000  17769.000000      ...                           1
#
#          smart_250_raw  smart_251_normalized    smart_251_raw  \
# count        97.000000                    97        97.000000
# mean   11923733.927835                     1  23080227.958763
# std     5127026.401610                     0   9900802.370172
# min      185364.000000                     1    362922.000000
# 25%     9628805.000000                     1  18777126.000000
# 50%    13643515.000000                     1  26489663.000000
# 75%    14091182.000000                     1  27119683.000000
# max    34378288.000000                     1  67014616.000000
#
#        smart_252_normalized    smart_252_raw  smart_254_normalized  \
# count                    97        97.000000            210.000000
# mean                      1  10791863.000000            111.904762
# std                       0   4640060.115495             32.461836
# min                       1    165243.000000            100.000000
# 25%                       1   8728485.000000            100.000000
# 50%                       1  12378874.000000            100.000000
# 75%                       1  12687044.000000            100.000000
# max                       1  31166139.000000            200.000000
#
#        smart_254_raw  smart_255_normalized  smart_255_raw
# count            210                     0              0
# mean               0                   NaN            NaN
# std                0                   NaN            NaN
# min                0                   NaN            NaN
# 25%                0                   NaN            NaN
# 50%                0                   NaN            NaN
# 75%                0                   NaN            NaN
# max                0                   NaN            NaN
#
# [8 rows x 82 columns]

# %% [markdown]
# #### Motivation to choose this dataset:
# - Real-world example of important non-deterministic process
# - Broad field for application of classic data analysis methods: clustering, time-series analysis, classification
# - Possible practical applications. E.g predict disk failures and avoid data loss
