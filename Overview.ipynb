# %% [markdown]
# # Overview of dataset
# ### Course: Data Analysis and Data Mining
# #### Authors: Andrey Kashin, Irina Osipova

# %% [markdown]
# Dataset source: https://www.backblaze.com/hard-drive-test-data.html

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Exploring sample of the data:

# %%
sample = pd.read_csv("data/2015-06-30.csv")

print("Size of sample: {}".format(len(sample)))
print("Number of features: {}".format(len(sample.columns)))

sample.head()
# Out:
# Size of sample: 48113
# Number of features: 95
#          date   serial_number                    model  capacity_bytes  \
# 0  2015-06-30  MJ0351YNG9Z0XA  Hitachi HDS5C3030ALA630   3000592982016
# 1  2015-06-30  MJ0351YNG9WJSA  Hitachi HDS5C3030ALA630   3000592982016
# 2  2015-06-30  MJ0351YNG9Z7LA  Hitachi HDS5C3030ALA630   3000592982016
# 3  2015-06-30  MJ0351YNGABYAA  Hitachi HDS5C3030ALA630   3000592982016
# 4  2015-06-30  PL2331LAGN2YTJ     HGST HMS5C4040BLE640   4000787030016
#
#    failure  smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 0        0                 100            0                 135          108
# 1        0                 100            0                 136          104
# 2        0                 100            0                 136          104
# 3        0                 100            0                 136          104
# 4        0                 100            0                 133          104
#
#    smart_3_normalized      ...        smart_250_normalized  smart_250_raw  \
# 0                 143      ...                         NaN            NaN
# 1                 127      ...                         NaN            NaN
# 2                 124      ...                         NaN            NaN
# 3                 137      ...                         NaN            NaN
# 4                 100      ...                         NaN            NaN
#
#    smart_251_normalized  smart_251_raw  smart_252_normalized  smart_252_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_254_normalized  smart_254_raw  smart_255_normalized  smart_255_raw
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
# [5 rows x 95 columns]

# %% [markdown]
# ### Simple statistics for numeric features of sample:

# %%
sample.describe()
# Out:
#        capacity_bytes       failure  smart_1_normalized   smart_1_raw  \
# count    4.811300e+04  48113.000000        48113.000000  4.811300e+04
# mean     3.586837e+12      0.000229          112.021616  5.421509e+07
# std      1.051388e+12      0.015119           22.106918  7.768088e+07
# min      8.002636e+10      0.000000            8.000000  0.000000e+00
# 25%      3.000593e+12      0.000000          100.000000  0.000000e+00
# 50%      4.000787e+12      0.000000          103.000000  0.000000e+00
# 75%      4.000787e+12      0.000000          117.000000  1.040629e+08
# max      8.001563e+12      1.000000          200.000000  3.171811e+09
#
#        smart_2_normalized   smart_2_raw  smart_3_normalized   smart_3_raw  \
# count        23755.000000  23755.000000        48113.000000  48113.000000
# mean           126.804041     74.354873          108.350155    467.988111
# std             21.103693     45.785827           20.467082   1218.818804
# min            100.000000      0.000000           71.000000      0.000000
# 25%            100.000000      0.000000           95.000000      0.000000
# 50%            133.000000    100.000000          100.000000      0.000000
# 75%            134.000000    104.000000          122.000000    560.000000
# max            252.000000    196.000000          253.000000   9691.000000
#
#        smart_4_normalized   smart_4_raw      ...        smart_250_normalized  \
# count        48113.000000  48113.000000      ...                          87
# mean            99.997901     17.415896      ...                           1
# std              0.168178    177.607017      ...                           0
# min             74.000000      1.000000      ...                           1
# 25%            100.000000      4.000000      ...                           1
# 50%            100.000000     10.000000      ...                           1
# 75%            100.000000     18.000000      ...                           1
# max            100.000000  26674.000000      ...                           1
#
#          smart_250_raw  smart_251_normalized  smart_251_raw  \
# count        87.000000                    87   8.700000e+01
# mean   59391010.540230                     1   1.199949e+08
# std    35610903.808723                     0   7.268761e+07
# min      108300.000000                     1   1.184700e+04
# 25%    22585207.500000                     1   4.464340e+07
# 50%    75257677.000000                     1   1.556657e+08
# 75%    90937876.000000                     1   1.838126e+08
# max    98353896.000000                     1   1.967209e+08
#
#        smart_252_normalized    smart_252_raw  smart_254_normalized  \
# count             87.000000        87.000000            195.000000
# mean               3.275862  54163472.988506            112.820513
# std               14.922817  32712797.706484             33.517861
# min                1.000000         0.000000            100.000000
# 25%                1.000000  20501584.000000            100.000000
# 50%                1.000000  69210546.000000            100.000000
# 75%                1.000000  82720427.500000            100.000000
# max              100.000000  90045286.000000            200.000000
#
#        smart_254_raw  smart_255_normalized  smart_255_raw
# count            195                     0              0
# mean               0                   NaN            NaN
# std                0                   NaN            NaN
# min                0                   NaN            NaN
# 25%                0                   NaN            NaN
# 50%                0                   NaN            NaN
# 75%                0                   NaN            NaN
# max                0                   NaN            NaN
#
# [8 rows x 92 columns]

# %% [markdown]
# #### Motivation to choose this dataset:
# - Real-world example of important non-deterministic process
# - Broad field for application of classic data analysis methods: clustering, time-series analysis, classification
# - Possible practical applications. E.g predict disk failures and avoid data loss

# %% [markdown]
# # Homework 2

# %%
sample["model"].unique()
# Out:
# array(['Hitachi HDS5C3030ALA630', 'HGST HMS5C4040BLE640', 'WDC WD30EFRX',
#        'Hitachi HDS5C4040ALE630', 'ST4000DM000', 'HGST HMS5C4040ALE640',
#        'ST6000DX000', 'Hitachi HDS723030ALA640', 'ST31500541AS',
#        'Hitachi HDS722020ALA330', 'ST33000651AS', 'WDC WD10EADS',
#        'ST4000DX000', 'WDC WD60EFRX', 'WDC WD5000LPVX',
#        'HGST HUH728080ALE600', 'ST31500341AS', 'ST320LT007',
#        'TOSHIBA MD04ABA500V', 'ST3000DM001', 'ST9320325AS', 'ST3160318AS',
#        'TOSHIBA MD04ABA400V', 'TOSHIBA DT01ACA300', 'WDC WD1600AAJS',
#        'ST9250315AS', 'ST3160316AS', 'ST500LM012 HN',
#        'Hitachi HDS724040ALE640', 'Hitachi HDS723020BLA642',
#        'WDC WD10EACS', 'WDC WD3200AAJB', 'WDC WD40EFRX',
#        'HGST HDS5C4040ALE630', 'WDC WD20EFRX', 'WDC WD800AAJS',
#        'WDC WD3200BEKX', 'HGST HDS724040ALE640', 'WDC WD800JB',
#        'WDC WD5000BPKT', 'ST250LM004 HN', 'Hitachi HDT725025VLA380',
#        'WDC WD10EADX', 'WDC WD1600AAJB', 'Hitachi HDS723030BLE640',
#        'WDC WD800AAJB', 'ST1500DL003', 'WDC WD800LB', 'WDC WD800BB',
#        'WDC WD3200AAJS', 'Hitachi HDS5C3030BLE630', 'WDC WD3200BEKT',
#        'WDC WD5002ABYS', 'ST250LT007', 'WDC WD2500AAJS', 'WDC WD2500BEVT',
#        'WDC WD2500BPVT', 'WDC WD5003ABYX', 'WDC WD2500AAJB', 'ST1500DL001',
#        'ST2000VN000', 'WDC WD15EARS', 'ST1500DM003', 'WDC WD10EARS',
#        'WDC WD3200LPVX', 'WDC WD800JD', 'SAMSUNG HD154UI',
#        'WDC WD1001FALS', 'WDC WD1600BPVT', 'ST3500320AS', 'WDC WD10EARX',
#        'WDC WD3200AAKS'], dtype=object)

# %% [markdown]
# ### Histogram of "Throughput Performance" of disk drives

# %%
sample["smart_2_normalized"].hist()

# %% [markdown]
# ### Histogram of "Capacity" of disk drives

# %%
sample["capacity_bytes"].hist()

# %%
disk_size_threshold = 2e12 # 2 terabytes

small_disks = sample[sample["capacity_bytes"] <= disk_size_threshold]
big_disks = sample[sample["capacity_bytes"] > disk_size_threshold]

# %%
print("Number of small disks: {}".format(len(small_disks)))
print("Number of big disks: {}".format(len(big_disks)))
# Out:
# Number of small disks: 2705
# Number of big disks: 45408

# %%
small_disks["smart_2_normalized"].hist()

# %%
big_disks["smart_2_normalized"].hist()
